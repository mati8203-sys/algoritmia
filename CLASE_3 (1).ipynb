# %% [markdown]
# CLASE 3

# %%
diccionario = {'curso 1' : [10, 5, 33, 45, 25, 22],
                 'curso 2' : [0, 15, 21, 30, 31, 11]}

# %%
print(diccionario)
# Out:
# {'curso 1': [10, 5, 33, 45, 25, 22], 'curso 2': [0, 15, 21, 30, 31, 11]}

# %%
import pandas as pd
s = pd.Series(['Juan', 'Amanda','Lorena', 'Claudia'], dtype='string')
print(s)
# Out:
# 0       Juan
# 1     Amanda
# 2     Lorena
# 3    Claudia
# dtype: string

# %%
import pandas as pd
s = pd.Series ({'Lorena': 16 , 'Juan': 18, 'Amanda' : 29 , 'Clauida' : 89})

print(s)
print(s.size)
print(s.index)
print(s.dtype)
print(s[1:3])
print(s.count)
# Out:
# Lorena     16
# Juan       18
# Amanda     29
# Clauida    89
# dtype: int64
# 4
# Index(['Lorena', 'Juan', 'Amanda', 'Clauida'], dtype='object')
# int64
# Juan      18
# Amanda    29
# dtype: int64
# <bound method Series.count of Lorena     16
# Juan       18
# Amanda     29
# Clauida    89
# dtype: int64>

# %% [markdown]
# extraer filas y columnas, hacer cosas a los datos

# %%
import pandas as pd
lista = {'nombre': ['Juan', 'Pedro','Antonia'],
                   'edad': [12,13,14],
                   'carrera':['ciencias','algoritmia', 'biologia']}
listo= pd.Series(lista)
print(listo)
# Out:
# nombre               [Juan, Pedro, Antonia]
# edad                           [12, 13, 14]
# carrera    [ciencias, algoritmia, biologia]
# dtype: object

# %%
import pandas as pd

import numpy as np

from datetime import datetime


indice = ['gerente', 'supervisor', 'vendedor', 'cajero']
personal = pd.DataFrame({'nombres':('Juan Pérez',
                                    'María Sánchez',
                                    'Jorge Vargas',
                                    'Rodrigo Martínez'),
            'fechas':(datetime(1995,12,21),
                      datetime(1989,1,13),
                      datetime(1992,9,14),
                      datetime(1993,7,8)),
            'saldo': (2500,
                      5345,
                      np.nan,
                      11323.2),
            'al corriente':(True,
                            True,
                            False,
                            True)}, index=indice)

# %%
print(personal)
# Out:
#                      nombres     fechas    saldo  al corriente
# gerente           Juan Pérez 1995-12-21   2500.0          True
# supervisor     María Sánchez 1989-01-13   5345.0          True
# vendedor        Jorge Vargas 1992-09-14      NaN         False
# cajero      Rodrigo Martínez 1993-07-08  11323.2          True

# %% [markdown]
# CONCATENAR
